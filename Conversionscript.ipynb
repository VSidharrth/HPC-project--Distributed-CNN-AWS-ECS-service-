# %%
# !pip install tensorflowjs

# %%
# !tensorflowjs_converter --input_format keras \
blood_cancer_model.h5 webs_model
# Out:
# 2025-11-08 13:46:17.250863: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762609577.284956    1327 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762609577.292689    1327 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762609577.312468    1327 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import shutil
shutil.make_archive("webs_model", 'zip', "webs_model")
# Out:
# '/content/webs_model.zip'
